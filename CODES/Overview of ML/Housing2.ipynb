# %%
# %run ./Housing.ipynb
# Out:
# /tmp/ipykernel_14288/45379878.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   housing['income_cat'].where(housing['income_cat'] < 5, 5.0, inplace = True)
# Predictions: [ 88983.14806384 305351.35385026 153334.71183453 184302.55162102
#  246840.18988841]
# Labels: [72100.0, 279600.0, 82700.0, 112500.0, 238300.0]
# Scores: [70241.3620656  68190.37715192 65072.64710408 68733.76442785
#  67523.6585125  68982.88006646 74718.31107716 69354.21593701
#  68276.37717213 71926.52068432]
# Mean: 69302.0114199016
# Standard deviation: 2467.2236056624656
# Scores: [72229.03469752 65318.2240289  67706.39604745 69368.53738998
#  66767.61061621 73003.75273869 70522.24414582 69440.77896541
#  66930.32945876 70756.31946074]
# Mean: 69204.32275494761
# Standard deviation: 2372.070791055918
# Scores: [50365.47428444 49442.42682169 46118.82915256 50406.73101809
#  47624.88514274 49427.5265093  51779.72843725 48690.01302078
#  47567.11938488 53116.22480187]
# Mean: 49453.89585735905
# Standard deviation: 1979.2230800444647
# DecisionTreeRegressor()
# 63941.04112095215 {'max_features': 2, 'n_estimators': 3}
# 55288.614456863455 {'max_features': 2, 'n_estimators': 10}
# 52622.07355876135 {'max_features': 2, 'n_estimators': 30}
# 52013.68113680588 {'max_features': 2, 'n_estimators': 40}
# 60355.55886858507 {'max_features': 4, 'n_estimators': 3}
# 53250.76045680183 {'max_features': 4, 'n_estimators': 10}
# 50516.37321647507 {'max_features': 4, 'n_estimators': 30}
# 50137.19338143146 {'max_features': 4, 'n_estimators': 40}
# 58862.42567482353 {'max_features': 6, 'n_estimators': 3}
# 51877.86494282176 {'max_features': 6, 'n_estimators': 10}
# 50054.150811113344 {'max_features': 6, 'n_estimators': 30}
# 49851.02693406503 {'max_features': 6, 'n_estimators': 40}
# 59043.72373751152 {'max_features': 8, 'n_estimators': 3}
# 51977.44662055417 {'max_features': 8, 'n_estimators': 10}
# 50186.63530723788 {'max_features': 8, 'n_estimators': 30}
# 49704.46372289417 {'max_features': 8, 'n_estimators': 40}
# 61902.12001405185 {'bootstrap': False, 'max_features': 2, 'n_estimators': 3}
# 53620.14488731299 {'bootstrap': False, 'max_features': 2, 'n_estimators': 10}
# 59475.470629680596 {'bootstrap': False, 'max_features': 3, 'n_estimators': 3}
# 52639.90043585461 {'bootstrap': False, 'max_features': 3, 'n_estimators': 10}
# 59244.2434861249 {'bootstrap': False, 'max_features': 4, 'n_estimators': 3}
# 51898.974782359895 {'bootstrap': False, 'max_features': 4, 'n_estimators': 10}

# %%
from sklearn.svm import SVR

svr = SVR()
svr.fit(housing_prepared,housing_labels)
housing_predictions = svr.predict(housing_prepared)
svr_scores = cross_val_score(svr,housing_prepared,housing_labels,
                             scoring = 'neg_mean_squared_error',cv = 3)
svr_rmse_scores = np.sqrt(-svr_scores)
display_scores(svr_rmse_scores)
# Out:
# Scores: [117077.74872025 118838.01419995 119506.72345727]
# Mean: 118474.1621258229
# Standard deviation: 1024.4578459396143
