# %%
# %matplotlib
import matplotlib.pyplot as plt
plt.style.use('seaborn-v0_8-whitegrid')
import numpy as np
# Out:
# Using matplotlib backend: module://matplotlib_inline.backend_inline

# %%
x = np.linspace(0,10,10)
y = np.sin(x)


plt.plot(x, y,'-.sg') #markers + linestyle + colors
plt.axis('auto')
# Out:
# (np.float64(-0.5),
#  np.float64(10.5),
#  np.float64(-1.062387867322411),
#  np.float64(1.0951686413375077))

# %%
rng = np.random.RandomState(0)
for marker in ['o', '.', ',', 'x', '+', 'v', '^', '<', '>', 's', 'd']:
    plt.plot(rng.rand(5), rng.rand(5), marker,
    label="marker='{0}'".format(marker))
    plt.legend(numpoints=1)
    plt.xlim(0, 1.8);

# %%
plt.scatter(x, y, marker='o')

# %%
# A Scatter plot of random points each of different properties.
rng = np.random.default_rng(seed=42)
x = rng.random(100)
y = rng.random(100)
colors = rng.random(100)
sizes = 1000 * rng.random(100)

plt.scatter(x,y, c = colors, s= sizes, alpha = 0.3, cmap = 'plasma')
plt.colorbar();
